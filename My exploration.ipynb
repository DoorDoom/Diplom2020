# %%
#Анализ информации с #https://webdevblog.ru/tematicheskoe-modelirovanie-s-pomoshhju-gensim-python/
# и # https://medium.com/@yanlinc/how-to-build-a-lda-topic-model-using-from-text-601cdcbfd3a6

# скачивание библиотек 
import numpy as np
import pandas as pd
import re, nltk, spacy, gensim
# Sklearn
from sklearn.decomposition import LatentDirichletAllocation, TruncatedSVD
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import GridSearchCV
from pprint import pprint
# Plotting tools
import pyLDAvis
import pyLDAvis.sklearn
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# medium.com ссылка на БД, данные этого типа можно открыть с помощью excel https://lumpics.ru/how-to-open-csv/
df = pd.read_csv('googlePlayStore_review_LDA.csv', error_bad_lines=False)
df = df.dropna(subset=['Translated_Review'])
df.head(14)
# Out:
#     Unnamed: 0                    App  \
# 0            0  10 Best Foods for You
# 1            1  10 Best Foods for You
# 2            3  10 Best Foods for You
# 3            4  10 Best Foods for You
# 4            5  10 Best Foods for You
# 5            6  10 Best Foods for You
# 6            8  10 Best Foods for You
# 7            9  10 Best Foods for You
# 8           10  10 Best Foods for You
# 9           11  10 Best Foods for You
# 10          12  10 Best Foods for You
# 11          13  10 Best Foods for You
# 12          14  10 Best Foods for You
# 13          16  10 Best Foods for You
#
#                                     Translated_Review Sentiment  \
# 0   I like eat delicious food. That's I'm cooking ...  Positive
# 1     This help eating healthy exercise regular basis  Positive
# 2          Works great especially going grocery store  Positive
# 3                                        Best idea us  Positive
# 4                                            Best way  Positive
# 5                                             Amazing  Positive
# 6                                Looking forward app,   Neutral
# 7               It helpful site ! It help foods get !   Neutral
# 8                                           good you.  Positive
# 9   Useful information The amount spelling errors ...  Positive
# 10  Thank you! Great app!! Add arthritis, eyes, im...  Positive
# 11  Greatest ever Completely awesome maintain heal...  Positive
# 12  Good health...... Good health first priority.....  Positive
# 13  Health It's important world either life . thin...  Positive
#
#     Sentiment_Polarity  Sentiment_Subjectivity                  Topic_key_word
# 0             1.000000                0.533333                 Account Problem
# 1             0.250000                0.288462        Download/Internet Access
# 2             0.400000                0.875000  Language/Recommend/Screen Size
# 3             1.000000                0.300000            Notification/Support
# 4             1.000000                0.300000            Notification/Support
# 5             0.600000                0.900000            Notification/Support
# 6             0.000000                0.000000                 Account Problem
# 7             0.000000                0.000000                 Account Problem
# 8             0.700000                0.600000            Notification/Support
# 9             0.200000                0.100000            Notification/Support
# 10            0.750000                0.875000                 Account Problem
# 11            0.992188                0.866667                    Photo/Search
# 12            0.550000                0.511111            Notification/Support
# 13            0.450000                1.000000                 Account Problem

# %%
# представление в виде листа
data = df.Translated_Review.values.tolist()
# удаление имейлов
data = [re.sub(r'\S*@\S*\s?', '', sent) for sent in data]
# удаление знаков припенания
data = [re.sub(r'\s+', ' ', sent) for sent in data]
# удаление ковычек '
data = [re.sub(r"\'", "", sent) for sent in data]
pprint(data[:1])
# Out:
# ['I like eat delicious food. Thats Im cooking food myself, case "10 Best '
#  'Foods" helps lot, also "Best Before (Shelf Life)"']

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True удаляет знак пунктуации
# перевод предложений в слова        
data_words = list(sent_to_words(data))
print(data_words[:1])
# Out:
# [['like', 'eat', 'delicious', 'food', 'thats', 'im', 'cooking', 'food', 'myself', 'case', 'best', 'foods', 'helps', 'lot', 'also', 'best', 'before', 'shelf', 'life']]

# %%
def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']): #'NOUN', 'ADJ', 'VERB', 'ADV'
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append(" ".join([token.lemma_ if token.lemma_ not in ['-PRON-'] else '' for token in doc if token.pos_ in allowed_postags]))
    return texts_out
# выполнение лемматизации (перевод слова в наипростойший его вид), работает с глаголами, существительными, прилагательными и причастиями

# %%
nlp = spacy.load('en', disable=['parser', 'ner'])
data_lemmatized = lemmatization(data_words, allowed_postags=['NOUN', 'VERB']) #выбирает сущиствительные и глаголы
print(data_lemmatized[:2])
# Out:
# ['eat food s be cook food case food help lot shelf life', 'help eat exercise basis']

# %%
vectorizer = CountVectorizer(analyzer='word',       
                             min_df=10,
# минимальные значения reqd в слове 
                             stop_words='english',             
# удаляет стоп слова
                             lowercase=True,                   
# переводит все свова в малый шрифт
                             token_pattern='[a-zA-Z0-9]{3,}',  
# слова содержат > 3 символов
                            max_features=50000,             
# максимальное количество слов uniq    
                            )
data_vectorized = vectorizer.fit_transform(data_lemmatized)

# %%
#  LDA Модель
lda_model = LatentDirichletAllocation(n_components=20,               # Количество тем
                                      max_iter=10,               
# иаксимальное число итераций
                                      learning_method='online',   
                                      random_state=100,          
# Random state
                                      batch_size=128,            
# n документов вкаждой обучающей итерации
                                      evaluate_every = -1,       
# вычислите несостыковки каждые n итераций, по умолчанию: не надо
                                      n_jobs = -1,               
# Использовать все возможные процессоры
                                     )
lda_output = lda_model.fit_transform(data_vectorized)
print(lda_model)  # параметры модели
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#                           evaluate_every=-1, learning_decay=0.7,
#                           learning_method='online', learning_offset=10.0,
#                           max_doc_update_iter=100, max_iter=10,
#                           mean_change_tol=0.001, n_components=20, n_jobs=-1,
#                           perp_tol=0.1, random_state=100, topic_word_prior=None,
#                           total_samples=1000000.0, verbose=0)

# %%
# Логарифмическая вероятность: чем выше, тем лучше
print("Log Likelihood: ", lda_model.score(data_vectorized))
# Смещение: чем ниже, тем лучше. смещение = exp(-1. * лог-вероятность на слово)
print("Perplexity: ", lda_model.perplexity(data_vectorized))

pprint(lda_model.get_params())
# Out:
# Log Likelihood:  -2047855.4042189221
# Perplexity:  1010.992229510251
# {'batch_size': 128,
#  'doc_topic_prior': None,
#  'evaluate_every': -1,
#  'learning_decay': 0.7,
#  'learning_method': 'online',
#  'learning_offset': 10.0,
#  'max_doc_update_iter': 100,
#  'max_iter': 10,
#  'mean_change_tol': 0.001,
#  'n_components': 20,
#  'n_jobs': -1,
#  'perp_tol': 0.1,
#  'random_state': 100,
#  'topic_word_prior': None,
#  'total_samples': 1000000.0,
#  'verbose': 0}

# %%
# Определение поисковых параметров
search_params = {'n_components': [10, 15, 20, 25, 30], 'learning_decay': [.5, .7, .9]}
# Инициализация модели
lda = LatentDirichletAllocation(max_iter=5, learning_method='online', learning_offset=50.,random_state=0)
# Инициализация графика для поиска оптимальной модели
model = GridSearchCV(lda, param_grid=search_params)
# Сделать поиск по графику
model.fit(data_vectorized)
GridSearchCV(cv=None, error_score='raise',
       estimator=LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
             evaluate_every=-1, learning_decay=0.7, learning_method=None,
             learning_offset=10.0, max_doc_update_iter=100, max_iter=10,
             mean_change_tol=0.001, n_components=10, n_jobs=1, perp_tol=0.1, random_state=None,
             topic_word_prior=None, total_samples=1000000.0, verbose=0),
        iid=True, n_jobs=1,
       param_grid={ 'learning_decay': [0.5, 0.7, 0.9]},
       pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
       scoring=None, verbose=0)
# Out:
# GridSearchCV(cv=None, error_score='raise',
#              estimator=LatentDirichletAllocation(batch_size=128,
#                                                  doc_topic_prior=None,
#                                                  evaluate_every=-1,
#                                                  learning_decay=0.7,
#                                                  learning_method=None,
#                                                  learning_offset=10.0,
#                                                  max_doc_update_iter=100,
#                                                  max_iter=10,
#                                                  mean_change_tol=0.001,
#                                                  n_components=10, n_jobs=1,
#                                                  perp_tol=0.1,
#                                                  random_state=None,
#                                                  topic_word_prior=None,
#                                                  total_samples=1000000.0,
#                                                  verbose=0),
#              iid=True, n_jobs=1, param_grid={'learning_decay': [0.5, 0.7, 0.9]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#              scoring=None, verbose=0)

# %%
# Лучшая модель
best_lda_model = model.best_estimator_
# Параметры модели
print("Best Model's Params: ", model.best_params_)
# Логарифмической вероятности счет
print("Best Log Likelihood Score: ", model.best_score_)
# Смещение
print("Model Perplexity: ", best_lda_model.perplexity(data_vectorized))
# Out:
# Best Model's Params:  {'learning_decay': 0.9, 'n_components': 10}
# Best Log Likelihood Score:  -682868.2210066896
# Model Perplexity:  745.1681902680335

# %%
# Создание документа — Topic Matrix (каждый документ- это строка)
lda_output = best_lda_model.transform(data_vectorized)
# Название колон
topicnames = ["Topic" + str(i) for i in range(best_lda_model.n_components)]
# Индекс имен
docnames = ["Doc" + str(i) for i in range(len(data))]
# Делаем  pandas ДБ
df_document_topic = pd.DataFrame(np.round(lda_output, 2), columns=topicnames, index=docnames)
# Получаем доминирующую тему для каждого документа
dominant_topic = np.argmax(df_document_topic.values, axis=1)
df_document_topic['dominant_topic'] = dominant_topic
# Стиль 
def color_green(val):
 color = 'green' if val > .1 else 'black'
 return 'color: {col}'.format(col=color)
def make_bold(val):
 weight = 700 if val > .1 else 400
 return 'font-weight: {weight}'.format(weight=weight)
# Применяем стиль
df_document_topics = df_document_topic.head(15).style.applymap(color_green).applymap(make_bold)
df_document_topics
# Out:
# <style  type="text/css" >
#     #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow0_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow0_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow0_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow0_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow0_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow0_col5 {
#             color:  green;
#             font-weight:  700;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow0_col6 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow0_col7 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow0_col8 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow0_col9 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow0_col10 {
#             color:  green;
#             font-weight:  700;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow1_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow1_col1 {
#             color:  green;
#             font-weight:  700;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow1_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow1_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow1_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow1_col5 {
#             color:  green;
#             font-weight:  700;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow1_col6 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow1_col7 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow1_col8 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow1_col9 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow1_col10 {
#             color:  green;
#             font-weight:  700;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow2_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow2_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow2_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow2_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow2_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow2_col5 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow2_col6 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow2_col7 {
#             color:  green;
#             font-weight:  700;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow2_col8 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow2_col9 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow2_col10 {
#             color:  green;
#             font-weight:  700;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow3_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow3_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow3_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow3_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow3_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow3_col5 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow3_col6 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow3_col7 {
#             color:  green;
#             font-weight:  700;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow3_col8 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow3_col9 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow3_col10 {
#             color:  green;
#             font-weight:  700;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow4_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow4_col1 {
#             color:  green;
#             font-weight:  700;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow4_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow4_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow4_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow4_col5 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow4_col6 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow4_col7 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow4_col8 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow4_col9 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow4_col10 {
#             color:  green;
#             font-weight:  700;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow5_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow5_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow5_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow5_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow5_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow5_col5 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow5_col6 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow5_col7 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow5_col8 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf362ferow5_col9 {
#             color:  black;
#             font-weight:  400;
#         }    #T_77c70e42_b665_11ea_a3fb_54e1adf3

# %%
# Матрица ключевых тематических слов
df_topic_keywords = pd.DataFrame(best_lda_model.components_)
# Назначение столбца и индекса
df_topic_keywords.columns = vectorizer.get_feature_names()
df_topic_keywords.index = topicnames
# Просмотр
df_topic_keywords.head(10)
# Out:
#           abandon    ability     abuse     accept      access  accessory  \
# Topic0   0.103101  22.533987  0.137453   0.106028    0.145951   0.102304
# Topic1   0.102084   0.106713  0.110340   0.113076    0.102733  10.864544
# Topic2   0.329840   0.102598  0.372234   0.102440    0.130243   0.110356
# Topic3  13.925415   0.117014  0.110713  62.898049  354.332934   0.101966
# Topic4   0.104097   1.081449  0.150666   0.103543    0.218386   0.112976
# Topic5   0.111952  86.977672  1.280292   0.103523    0.119549   0.113185
# Topic6   0.102973  15.932910  0.102345  34.234885  203.801347   0.103184
# Topic7  11.039980  89.248515  8.672795   0.103298    1.020447   0.102162
# Topic8   0.161943   7.441495  0.211621   2.001336    1.770109   0.102317
# Topic9   0.102404  51.024820  4.921801  15.506010    0.856515   0.102479
#
#         accident  accommodation  accomplish     accord  ...       yard  \
# Topic0  4.021734       0.109082   10.091014  39.644300  ...   0.106333
# Topic1  4.080986       0.109971    3.681558   0.103889  ...   0.106721
# Topic2  0.106858       0.102286    0.109104   0.102076  ...   0.101730
# Topic3  0.113849       0.110195    0.102764   0.102409  ...   1.650556
# Topic4  0.104940       0.104079    0.103065   0.127591  ...   0.113832
# Topic5  0.102310       9.986152    0.105586   0.110693  ...   0.103671
# Topic6  0.106111       0.102406    0.141298   0.103284  ...   0.102304
# Topic7  0.101918       0.103705    0.105860   0.111832  ...   0.118607
# Topic8  0.102607       0.101739    1.059646   0.104442  ...  13.923000
# Topic9  2.524751       0.102047    0.174812   0.103131  ...   0.102784
#
#           yardage        year  yesterday       yoga    youtube        zip  \
# Topic0   2.640943  623.268152   0.105581   0.126286   0.103588   0.104383
# Topic1   0.518119    9.380789   0.105139   0.104323   0.112643   0.571572
# Topic2   0.167430  172.196196   0.103916   0.102372   0.110872   0.132471
# Topic3   0.761813    0.155832   0.103092   0.111545  54.271845   0.149447
# Topic4   0.268793   49.673073   2.487472  50.396425   0.103758   0.108240
# Topic5   6.281533   23.087260   0.102960   0.104129   0.105476   0.101731
# Topic6   1.808783   65.645394  25.547233   0.107675   0.110253   0.104007
# Topic7  15.616988  168.744166  54.267998   0.252732  15.887032   0.113292
# Topic8   0.406436  138.661628   0.141585   4.174419   0.300220   0.104665
# Topic9   0.942590   96.568847   0.120616   0.104714   0.301564  16.551021
#
#            zombie       zone       zoom
# Topic0   0.103681   0.107657   0.102542
# Topic1   0.106857   0.299574  32.349009
# Topic2  15.932525  14.517187   0.104326
# Topic3   0.108190   0.326489  28.708928
# Topic4   0.277668   0.105378  10.861245
# Topic5   0.114951   0.102276   0.108070
# Topic6   0.103550  10.233266   0.142608
# Topic7   0.102026   0.109462   0.456546
# Topic8   0.109028   1.330913   0.105551
# Topic9   2.843389   1.855875   0.108774
#
# [10 rows x 2172 columns]

# %%
# Показать самые используемые ключевые слова для кадждой темы
def show_topics(vectorizer=vectorizer, lda_model=lda_model, n_words=20):
    keywords = np.array(vectorizer.get_feature_names())
    topic_keywords = []
    for topic_weights in lda_model.components_:
        top_keyword_locs = (-topic_weights).argsort()[:n_words]
        topic_keywords.append(keywords.take(top_keyword_locs))
    return topic_keywords
topic_keywords = show_topics(vectorizer=vectorizer, lda_model=best_lda_model, n_words=15)
# Тема-ключевое слово БД
df_topic_keywords = pd.DataFrame(topic_keywords)
df_topic_keywords.columns = ['Word '+str(i) for i in range(df_topic_keywords.shape[1])]
df_topic_keywords.index = ['Topic '+str(i) for i in range(df_topic_keywords.shape[0])]
df_topic_keywords
# Out:
#           Word 0 Word 1   Word 2     Word 3  Word 4  Word 5  Word 6 Word 7  \
# Topic 0      use   need    thank  recommend     app    year    news   date
# Topic 1  problem   look      way    picture   think   color    deal   work
# Topic 2     game   play    level        fun    make   money  player  spend
# Topic 3   screen  video     hate     change     guy  access   datum  enter
# Topic 4     star  thing     make      photo     way   month     fix   lose
# Topic 5      lot   help     book      price   check    food  option  learn
# Topic 6     time    try  account        let    work    card     ask   need
# Topic 7   update   work      app    version  people    know    user   read
# Topic 8    phone   make      day      money    send  minute   email    try
# Topic 9     love    add      pay        say     fix    tell    want  thing
#
#                Word 8      Word 9    Word 10      Word 11  Word 12  Word 13  \
# Topic 0      download        want      story        enjoy    start   person
# Topic 1         order  understand     choice      episode     help  product
# Topic 2         start       thing  character          buy    think  graphic
# Topic 3   application      second       file       button  article    force
# Topic 4          item        miss      track      content    share     help
# Topic 5     developer      choose    feature  information     stay    thank
# Topic 6           log      device      waste        crash    watch     want
# Topic 7  notification      option     review         page     want     stop
# Topic 8          life        save        app       instal     site  receive
# Topic 9          star         app       work         list    thank     load
#
#           Word 14
# Topic 0       car
# Topic 1  customer
# Topic 2   control
# Topic 3       job
# Topic 4       bar
# Topic 5       bit
# Topic 6      load
# Topic 7      note
# Topic 8  purchase
# Topic 9      like

# %%
# по возможности темы вводятся самостоятельно
Topics = ['Topic '+str(i) for i in range(df_topic_keywords.shape[0])]
df_topic_keywords["Topics"]=Topics
df_topic_keywords
# Out:
#           Word 0 Word 1   Word 2     Word 3  Word 4  Word 5  Word 6 Word 7  \
# Topic 0      use   need    thank  recommend     app    year    news   date
# Topic 1  problem   look      way    picture   think   color    deal   work
# Topic 2     game   play    level        fun    make   money  player  spend
# Topic 3   screen  video     hate     change     guy  access   datum  enter
# Topic 4     star  thing     make      photo     way   month     fix   lose
# Topic 5      lot   help     book      price   check    food  option  learn
# Topic 6     time    try  account        let    work    card     ask   need
# Topic 7   update   work      app    version  people    know    user   read
# Topic 8    phone   make      day      money    send  minute   email    try
# Topic 9     love    add      pay        say     fix    tell    want  thing
#
#                Word 8      Word 9    Word 10      Word 11  Word 12  Word 13  \
# Topic 0      download        want      story        enjoy    start   person
# Topic 1         order  understand     choice      episode     help  product
# Topic 2         start       thing  character          buy    think  graphic
# Topic 3   application      second       file       button  article    force
# Topic 4          item        miss      track      content    share     help
# Topic 5     developer      choose    feature  information     stay    thank
# Topic 6           log      device      waste        crash    watch     want
# Topic 7  notification      option     review         page     want     stop
# Topic 8          life        save        app       instal     site  receive
# Topic 9          star         app       work         list    thank     load
#
#           Word 14   Topics
# Topic 0       car  Topic 0
# Topic 1  customer  Topic 1
# Topic 2   control  Topic 2
# Topic 3       job  Topic 3
# Topic 4       bar  Topic 4
# Topic 5       bit  Topic 5
# Topic 6      load  Topic 6
# Topic 7      note  Topic 7
# Topic 8  purchase  Topic 8
# Topic 9      like  Topic 9

# %%
# Определите тему для данного текстового документа.
nlp = spacy.load('en', disable=['parser', 'ner'])
def predict_topic(text, nlp=nlp):
    global sent_to_words
    global lemmatization
    mytext_2 = list(sent_to_words(text))
    mytext_3 = lemmatization(mytext_2, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])
    mytext_4 = vectorizer.transform(mytext_3)
    topic_probability_scores = best_lda_model.transform(mytext_4)
    topic = df_topic_keywords.iloc[np.argmax(topic_probability_scores), 1:14].values.tolist()
    infer_topic = df_topic_keywords.iloc[np.argmax(topic_probability_scores), -1]
    
    #topic_guess = df_topic_keywords.iloc[np.argmax(topic_probability_scores), Topics]
    return infer_topic, topic, topic_probability_scores
# Predict the topic
mytext = ["Experience with content management systems a major plus (any blogging counts!)Familiar with the Food52 editorial voice and aestheticLoves food, appreciates the importance of home cooking and cooking with the seasonsMeticulous editor, perfectionist, obsessive attention to detail, maddened by typos and broken links, delighted by finding and fixing themCheerful under pressureExcellent communication skillsA+ multi-tasker and juggler of responsibilities big and smallInterested in and engaged with social media like Twitter, Facebook, and PinterestLoves problem-solving and collaborating to drive Food52 forwardThinks big picture but pitches in on the nitty gritty of running a small company (dishes, shopping, administrative support)Comfortable with the realities of working for a startup: being on call on evenings and weekends, and working long hours"]
infer_topic, topic, prob_scores = predict_topic(text = mytext)
print(topic)
print(infer_topic)
# Out:
# ['work', 'app', 'version', 'people', 'know', 'user', 'read', 'notification', 'option', 'review', 'page', 'want', 'stop']
# Topic 7

# %%
# Тестирование.
data1 = df.Translated_Review.values.tolist()
list1=[]
list2=[]
list3=[]
text1=data1[0]
z=0
x=0
for txt in data1:
    text1=txt
    list1.append(text1)
    infer_topic, topic, prob_scores = predict_topic(text=list1)
    list2.append(int(infer_topic[6]))
    list1.clear()
for i in range(len(list2)):
    z=z+1
    if dominant_topic[i]==list2[i]:
        x=x+1
print(x,z)
# Out:
# 29721 37427
